# %% [markdown]
# # Python Assignment: Data Structures, Functions, Numpy & Pandas

# %% [markdown]
# ## Section A: Data Structures & Control Structures

# %% [raw]
# 1.	Create a list of 5 integers. Perform and print the result of the following operations: append, extend, insert, remove, pop, clear, index, count, sort, and reverse.

# %%
lst1=[12,4,65,39,78]
lst1
# Out:
# [12, 4, 65, 39, 78]

# %%
type(lst1)
# Out:
# list

# %%
### append
lst1.append(90)
lst1
# Out:
# [12, 4, 65, 39, 78, 90]

# %%
### extend
lst1.extend([20,39,40])

# %%
lst1
# Out:
# [12, 4, 65, 39, 78, 90, 20, 39, 40]

# %%
### insert
lst1.insert(0,3)
lst1
# Out:
# [3, 12, 4, 65, 39, 78, 90, 20, 39, 40]

# %%
### remove
lst1.remove(78)
lst1
# Out:
# [3, 12, 4, 65, 39, 90, 20, 39, 40]

# %%
### pop
lst1.pop(3)
lst1
# Out:
# [3, 12, 4, 39, 90, 20, 39, 40]

# %%
### index
lst1.index(39,4)
# Out:
# 6

# %%
### count
lst1.count(39)
# Out:
# 2

# %%
### sort
lst1.sort()
lst1
# Out:
# [3, 4, 12, 20, 39, 39, 40, 90]

# %%
### reverse
lst1.reverse()
lst1
# Out:
# [90, 40, 39, 39, 20, 12, 4, 3]

# %%
### clear
lst1.clear()
lst1
# Out:
# []

# %% [raw]
# 2.	Create a tuple that stores 3 student names. Try changing the second name in the tuple. What happens? Explain why.

# %%
student_name=('Karthik','Abhishek','Tharunika')
student_name
# Out:
# ('Karthik', 'Abhishek', 'Tharunika')

# %%
type(student_name)
# Out:
# tuple

# %%
# student_name[2]='Tharu'

# %% [markdown]
# * If we try to change the name we will get error.
# * In tuple we cant chnage the enteries  because tuples are immutable (unchangeable).

# %% [raw]
# 3.	Create a set of integers with some duplicate values. Print the set and explain the output.

# %%
set1={80,250,345,25,142,300,25}

# %%
type(set1)
# Out:
# set

# %%
set1
# Out:
# {25, 80, 142, 250, 300, 345}

# %% [markdown]
# * Set removes the duplicates if present, the output shows only once and keep unique items.
#   Here 25 is written twice in the set but in output the 25 is written only once.
# * Set shuffles the order and output is printed in ascending order.

# %% [raw]
# 4.	Create a dictionary with the keys: 'name', 'age', and 'city'. Update the age and add a new key 'email'. Print the final dictionary.

# %%
dict1={'name':['Karthik','Abhishek','Tharunika'],
       'age':[23,21,13],
       'city':['Bangalore','Mysore','Chintamani']
      }
dict1
# Out:
# {'name': ['Karthik', 'Abhishek', 'Tharunika'],
#  'age': [23, 21, 13],
#  'city': ['Bangalore', 'Mysore', 'Chintamani']}

# %%
type(dict1)
# Out:
# dict

# %%
dict1['age'][2]=8
dict1
# Out:
# {'name': ['Karthik', 'Abhishek', 'Tharunika'],
#  'age': [23, 21, 8],
#  'city': ['Bangalore', 'Mysore', 'Chintamani']}

# %%
dict1['email']=['karthikrs@gmail.com','abhishek@gmail.com','tharunika@gmail.com']

# %%
dict1
# Out:
# {'name': ['Karthik', 'Abhishek', 'Tharunika'],
#  'age': [23, 21, 8],
#  'city': ['Bangalore', 'Mysore', 'Chintamani'],
#  'email': ['karthikrs@gmail.com', 'abhishek@gmail.com', 'tharunika@gmail.com']}

# %% [raw]
# 5. Write a script that checks if a person is eligible to vote (age ≥ 18). Take age as a variable and print the appropriate message.

# %%
age = int(input("Enter your age to check eligibility for voting: "))

if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote yet.")
# Out:
# Enter your age to check eligibility for voting:  23
# You are eligible to vote

# %% [raw]
# 6.	Given a 'marks' variable, print the grade:
#     - 90 and above: 'A'
#     - 75–89: 'B'
#     - 50–74: 'C'
#     - Below 50: 'Fail'

# %%
marks = int(input("Enter your marks to get the Grade: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 50:
    print("Grade: C")
else:
    print("Grade: Fail")
# Out:
# Enter your marks to get the Grade:  68
# Grade: C

# %% [raw]
# 7.	Given a number, check if it's positive, and if it is also even. If not positive, print if it's zero or negative.

# %%
num = int(input("Enter a number: "))

if num > 0:
    if num % 2 == 0:
        print(f"The number {num} is positive and even.")
    else:
        print(f"The number {num} is positive but odd.")

elif num == 0:
    print("The number is zero.")

else:
    print(f"The number {num} is negative.")
# Out:
# Enter a number:  7
# The number 7 is positive but odd.

# %% [markdown]
# ## Section B: Numpy

# %% [raw]
# 8.	Create:
# - A scalar using np.array(5)

# %%
import numpy as np
scalar=np.array(5)
scalar
# Out:
# array(5)

# %% [raw]
# - A 1D array with values 1 to 5

# %%
arr_1D=np.arange(1,6)
arr_1D
# Out:
# array([1, 2, 3, 4, 5])

# %% [raw]
# - A 2D array (2x3) with values from 10 to 60 in steps of 10

# %%
arr_2D=np.array([10,20,30,40,50,60]).reshape(2,3)
arr_2D
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %% [raw]
# 9.	Generate a 4x4 Numpy array of random integers between 0 and 100 using np.random.randint().

# %%
rand_arr=np.random.randint(0,100, size=(4,4))
rand_arr
# Out:
# array([[83, 93, 83, 91],
#        [29, 74, 10, 27],
#        [24, 45, 62, 67],
#        [19,  2, 73, 32]], dtype=int32)

# %% [raw]
# 10.	Create a 2D numpy array of shape (3x3). Convert it into a pandas DataFrame and add column names: 'A', 'B', 'C'.

# %%
arr_2D=np.array([10,15,20,30,35,40,45,50,55]).reshape(3,3)
arr_2D
# Out:
# array([[10, 15, 20],
#        [30, 35, 40],
#        [45, 50, 55]])

# %%
import pandas as pd
data=pd.DataFrame(arr_2D, columns=['A', 'B','C'])
data
# Out:
#     A   B   C
# 0  10  15  20
# 1  30  35  40
# 2  45  50  55

# %% [markdown]
# ## Section C: Exploring Pandas

# %% [raw]
# 11.	Create a small DataFrame manually with 10 rows and columns: 'Name', 'Age', 'City', and 'Salary'. Then:
# - Use .info(), .describe()
# - Select 'Name' and 'City' columns
# - Drop 'City' column
# - Fill any missing values in 'Salary' column with the mean
# - Remove any duplicate rows

# %%
df={'Name': ['Aravind', 'Ananya', 'Vinay', 'Divya', 'Kabir', 'Isha', 'Arjun', 'Meera', 'Aravind', 'Rohan'],
    'Age': [25, 30, 22, 28, 35, 29, 40, 31, 25, 27],
    'City': ['Mumbai', 'Delhi', 'Bangalore', 'Hyderabad', 'Pune', 'Chennai', 'Kolkata', 'Ahmedabad', 'Mumbai', 'Jaipur'],
    'Salary': [70000, np.nan, 85000, 95000, 60000, np.nan, 52000, 88000, 70000, 62000]
   }
df
# Out:
# {'Name': ['Aravind',
#   'Ananya',
#   'Vinay',
#   'Divya',
#   'Kabir',
#   'Isha',
#   'Arjun',
#   'Meera',
#   'Aravind',
#   'Rohan'],
#  'Age': [25, 30, 22, 28, 35, 29, 40, 31, 25, 27],
#  'City': ['Mumbai',
#   'Delhi',
#   'Bangalore',
#   'Hyderabad',
#   'Pune',
#   'Chennai',
#   'Kolkata',
#   'Ahmedabad',
#   'Mumbai',
#   'Jaipur'],
#  'Salary': [70000, nan, 85000, 95000, 60000, nan, 52000, 88000, 70000, 62000]}

# %%
df=pd.DataFrame(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    10 non-null     object
#  3   Salary  8 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count  10.000000      8.000000
# mean   29.200000  72750.000000
# std     5.245104  15125.664094
# min    22.000000  52000.000000
# 25%    25.500000  61500.000000
# 50%    28.500000  70000.000000
# 75%    30.750000  85750.000000
# max    40.000000  95000.000000

# %%
df[['Name','City']]
# Out:
#       Name       City
# 0  Aravind     Mumbai
# 1   Ananya      Delhi
# 2    Vinay  Bangalore
# 3    Divya  Hyderabad
# 4    Kabir       Pune
# 5     Isha    Chennai
# 6    Arjun    Kolkata
# 7    Meera  Ahmedabad
# 8  Aravind     Mumbai
# 9    Rohan     Jaipur

# %%
df.drop(columns=['City'])
# Out:
#       Name  Age   Salary
# 0  Aravind   25  70000.0
# 1   Ananya   30      NaN
# 2    Vinay   22  85000.0
# 3    Divya   28  95000.0
# 4    Kabir   35  60000.0
# 5     Isha   29      NaN
# 6    Arjun   40  52000.0
# 7    Meera   31  88000.0
# 8  Aravind   25  70000.0
# 9    Rohan   27  62000.0

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# City      0
# Salary    2
# dtype: int64

# %%
mean_salary=df['Salary'].mean()
mean_salary
# Out:
# np.float64(72750.0)

# %%
df.fillna({'Salary': mean_salary}, inplace=True)
df['Salary']
# Out:
# 0    70000.0
# 1    72750.0
# 2    85000.0
# 3    95000.0
# 4    60000.0
# 5    72750.0
# 6    52000.0
# 7    88000.0
# 8    70000.0
# 9    62000.0
# Name: Salary, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#       Name  Age    City   Salary
# 8  Aravind   25  Mumbai  70000.0

# %%
df.drop_duplicates(inplace=True,ignore_index=True)
df
# Out:
#       Name  Age       City   Salary
# 0  Aravind   25     Mumbai  70000.0
# 1   Ananya   30      Delhi  72750.0
# 2    Vinay   22  Bangalore  85000.0
# 3    Divya   28  Hyderabad  95000.0
# 4    Kabir   35       Pune  60000.0
# 5     Isha   29    Chennai  72750.0
# 6    Arjun   40    Kolkata  52000.0
# 7    Meera   31  Ahmedabad  88000.0
# 8    Rohan   27     Jaipur  62000.0
